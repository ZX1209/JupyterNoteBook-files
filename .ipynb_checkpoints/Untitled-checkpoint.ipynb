# %%
# commont this
html_page ='''
<form name="xskb_form" method="post" action="xskbcx.aspx?xh=202160621&amp;xm=%B8%DF%C1%EC&amp;gnmkdm=N121603" id="xskb_form">
<input type="hidden" name="__EVENTTARGET" value="">
<input type="hidden" name="__EVENTARGUMENT" value="">
<input type="hidden" name="__VIEWSTATE" value="...">

<script language="javascript" type="text/javascript">
<!--
	function __doPostBack(eventTarget, eventArgument) {
		var theform;
		if (window.navigator.appName.toLowerCase().indexOf("microsoft") > -1) {
			theform = document.xskb_form;
		}
		else {
			theform = document.forms["xskb_form"];
		}
		theform.__EVENTTARGET.value = eventTarget.split("$").join(":");
		theform.__EVENTARGUMENT.value = eventArgument;
		theform.submit();
	}
// -->
</script>

			<!-- 多功能操作区 -->
			<!-- 内容显示区开始 -->
			<div class="main_box ">
				<div class="mid_box">
					<div class="title noprint">
						<p>
							<!-- 查询得到的数据量显示区域 --></p>
					</div>
					<!-- From内容 --><span class="formbox">
						<table class="formlist noprint" id="Table2" width="100%">
							<tbody><tr>
								<td align="center"><select name="xnd" onchange="__doPostBack('xnd','')" language="javascript" id="xnd">
	<option selected="selected" value="2018-2019">2018-2019</option>
	<option value="2017-2018">2017-2018</option>
	<option value="2016-2017">2016-2017</option>

</select><span id="Label2"><font size="4">学年第</font></span><select name="xqd" onchange="__doPostBack('xqd','')" language="javascript" id="xqd">
	<option selected="selected" value="1">1</option>
	<option value="2">2</option>
	<option value="3">3</option>

</select><span id="Label1"><font size="4">学期学生个人课程表</font></span></td>
							</tr>
							<tr class="trbg1">
								<td><span id="Label5">学号：202160621</span>|
									<span id="Label6">姓名：高领</span>|
									<span id="Label7">学院：计算机工程学院</span>|
									<span id="Label8">专业：数字媒体技术(嵌入式培养)</span>|
									<span id="Label9">行政班：数字媒体(嵌入)162</span>
									&nbsp;&nbsp;&nbsp;&nbsp;<span id="labTS"><font color="Red"></font></span><span id="labTip"><font color="Red"></font></span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input name="btnPrint" id="btnPrint" type="button" class="button" style="DISPLAY:none" onclick="window.print();" value="打印课表">
								</td>
							</tr>
						</tbody></table>
						
						<br>
						<table id="Table1" class="blacktab" bordercolor="Black" border="0" width="100%">
	<tbody><tr>
		<td colspan="2" rowspan="1" width="2%">时间</td><td align="Center" width="14%">星期一</td><td align="Center" width="14%">星期二</td><td align="Center" width="14%">星期三</td><td align="Center" width="14%">星期四</td><td align="Center" width="14%">星期五</td><td class="noprint" align="Center" width="14%">星期六</td><td class="noprint" align="Center" width="14%">星期日</td>
	</tr><tr>
		<td colspan="2">早晨</td><td align="Center">&nbsp;</td><td align="Center">&nbsp;</td><td align="Center">&nbsp;</td><td align="Center">&nbsp;</td><td align="Center">&nbsp;</td><td class="noprint" align="Center">&nbsp;</td><td class="noprint" align="Center">&nbsp;</td>
	</tr><tr>
		<td rowspan="4" width="1%">上午</td><td width="1%">第1节</td><td align="Center" rowspan="2" width="7%">数据库原理及应用A<br>必修<br>周一第1,2节{第1-3周|单周}<br>夏官梦<br>经管D304<br><br>数据库原理及应用A<br>必修<br>周一第1,2节{第7-13周|单周}<br>夏官梦<br>经管D304</td><td align="Center" rowspan="2" width="7%">操作系统A<br>必修<br>周二第1,2节{第1-4周}<br>刘晓璐<br>经管D403<br><br>操作系统A<br>必修<br>周二第1,2节{第6-13周}<br>刘晓璐<br>经管D403</td><td align="Center" width="7%">&nbsp;</td><td align="Center" rowspan="2" width="7%">操作系统A<br>必修<br>周四第1,2节{第1-4周}<br>刘晓璐<br>经管D403<br><br>操作系统A<br>必修<br>周四第1,2节{第6-13周}<br>刘晓璐<br>经管D403</td><td align="Center" width="7%">&nbsp;</td><td class="noprint" align="Center" width="7%">&nbsp;</td><td class="noprint" align="Center" width="7%">&nbsp;</td>
	</tr><tr>
		<td>第2节</td><td align="Center">&nbsp;</td><td align="Center">&nbsp;</td><td class="noprint" align="Center">&nbsp;</td><td class="noprint" align="Center">&nbsp;</td>
	</tr><tr>
		<td>第3节</td><td align="Center" rowspan="2">计算机组成与结构<br>必修<br>周一第3,4节{第3-3周|单周}<br>钱瑛<br>经管C404<br><br><font color="red">(调0731)</font><br><br>计算机组成与结构<br>必修<br>周一第3,4节{第7-13周|单周}<br>钱瑛<br>经管C404<br><br><font color="red">(调0731)</font></td><td align="Center" rowspan="2">WEB开发技术<br>任选<br>周二第3,4节{第1-4周}<br>程初<br>经管D404<br><br>WEB开发技术<br>任选<br>周二第3,4节{第6-13周}<br>程初<br>经管D404</td><td align="Center" rowspan="2">JAVA基础<br>必修<br>周三第3,4节{第6-13周}<br>范大娟<br>经管D104<br><br>JAVA基础<br>必修<br>周三第3,4节{第1-4周}<br>范大娟<br>经管D104</td><td align="Center" rowspan="2">WEB开发技术<br>任选<br>周四第3,4节{第1-4周}<br>程初<br>经管D404<br><br>WEB开发技术<br>任选<br>周四第3,4节{第6-13周}<br>程初<br>经管D404</td><td align="Center" rowspan="2">JAVA基础<br>必修<br>周五第3,4节{第1-4周}<br>范大娟<br>信息B201<br><br>JAVA基础<br>必修<br>周五第3,4节{第6-13周}<br>范大娟<br>信息B201</td><td class="noprint" align="Center">&nbsp;</td><td class="noprint" align="Center" rowspan="2">计算机组成与结构<br>必修<br>周日第3,4节{第4-4周|双周}<br>钱瑛<br>经管C404</td>
	</tr><tr>
		<td>第4节</td><td class="noprint" align="Center">&nbsp;</td>
	</tr><tr>
		<td rowspan="4" width="1%">下午</td><td>第5节</td><td align="Center" rowspan="2">数字图像处理技术<br>必修<br>周一第5,6节{第6-13周}<br>林忠<br>经管C211<br><br><font color="red">(调0689)</font><br><br>数字图像处理技术<br>必修<br>周一第5,6节{第1-3周}<br>林忠<br>经管C211<br><br><font color="red">(调0689)</font></td><td align="Center" rowspan="2">计算机组成与结构<br>必修<br>周二第5,6节{第2-4周}<br>钱瑛<br>经管D103<br><br><font color="red">(调0732)</font><br><br>计算机组成与结构<br>必修<br>周二第5,6节{第6-13周}<br>钱瑛<br>经管D103<br><br><font color="red">(调0732)</font></td><td align="Center">&nbsp;</td><td align="Center" rowspan="2">计算机组成与结构<br>必修<br>周四第5,6节{第6-13周}<br>钱瑛<br>经管D103<br><br><font color="red">(调0733)</font><br><br>计算机组成与结构<br>必修<br>周四第5,6节{第2-4周}<br>钱瑛<br>经管D103<br><br><font color="red">(调0733)</font></td><td align="Center" rowspan="2">数据库原理及应用A<br>必修<br>周五第5,6节{第1-4周}<br>夏官梦<br>经管D304<br><br>数据库原理及应用A<br>必修<br>周五第5,6节{第6-14周}<br>夏官梦<br>经管D304</td><td class="noprint" align="Center" rowspan="2">数字图像处理技术<br>必修<br>周六第5,6节{第4-4周|双周}<br>林忠<br>经管C211</td><td class="noprint" align="Center">&nbsp;</td>
	</tr><tr>
		<
	</tr><tr>
		<td>调0733</td><td>计算机组成与结构</td><td>周4第5节连续2节{第1-1周}/经管D103/钱瑛</td><td>周4第5节连续2节{第13-13周单周}/经管D103/钱瑛</td><td>2018-07-14-17-59</td>
	</tr>
</tbody></table>
						<table class="noprint" id="Table3" width="100%">
							<tbody><tr id="tr_sjk">
	<td align="left">实践课(或无上课时间)信息：</td>
</tr>

							<tr id="tr_dtsjk">
	<td valign="top"><table class="datelist" cellspacing="0" cellpadding="3" border="0" id="DataGrid1" width="100%">
		<tbody><tr class="datelisthead">
			<td>课程名称</td><td>教师</td><td>学分</td><td>起止周</td><td>上课时间</td><td>上课地点</td>
		</tr><tr>
			<td>多媒体技术课程设计</td><td>卢阿丽</td><td>1.0</td><td>17-17</td><td>&nbsp;</td><td>&nbsp;</td>
		</tr><tr class="alt">
			<td>数据库原理及应用课设</td><td>夏官梦</td><td>1.0</td><td>18-18</td><td>&nbsp;</td><td>&nbsp;</td>
		</tr><tr>
			<td>操作系统课程设计</td><td>刘晓璐</td><td>1.0</td><td>19-19</td><td>&nbsp;</td><td>&nbsp;</td>
		</tr><tr class="alt">
			<td>数字图像处理技术课设</td><td>林忠</td><td>1.0</td><td>16-16</td><td>&nbsp;</td><td>&nbsp;</td>
		</tr>
	</tbody></table></td>
</tr>

							<tr>
								<td align="left">实习课信息：</td>
							</tr>
							<tr>
								<td><table class="datelist" cellspacing="0" cellpadding="3" border="0" id="DBGridYxkc" width="100%">
	<tbody><tr class="datelisthead">
		<td>学年</td><td>学期</td><td>课程名称</td><td>实习时间</td><td>模块代号</td><td>先修模块</td><td>实习编号</td>
	</tr>
</tbody></table></td>
							</tr>
							<tr id="tr_wap">
	<td align="left">未安排上课时间的课程：</td>
</tr>

							<tr id="tr_dtwap">
	<td><table class="datelist" cellspacing="0" cellpadding="3" border="0" id="Datagrid2" width="100%">
		<tbody><tr class="datelisthead">
			<td>学年</td><td>学期</td><td>课程名称</td><td>教师姓名</td><td>学分</td>
		</tr><tr>
			<td>2018-2019</td><td>1</td><td>数据库原理及应用课设</td><td>夏官梦</td><td>1.0</td>
		</tr><tr class="alt">
			<td>2018-2019</td><td>1</td><td>数字图像处理技术课设</td><td>林忠</td><td>1.0</td>
		</tr><tr>
			<td>2018-2019</td><td>1</td><td>多媒体技术课程设计</td><td>卢阿丽</td><td>1.0</td>
		</tr><tr class="alt">
			<td>2018-2019</td><td>1</td><td>操作系统课程设计</td><td>刘晓璐</td><td>1.0</td>
		</tr>
	</tbody></table></td>
</tr>

						</tbody></table>
					</span>
					<div class="footbox noprint"><em class="footbox_con"><span class="pagination"></span>
							<span class="footbutton"></span>
							<!-- 底部按钮位置 --></em></div>
				</div>
			</div>
		</form>

'''

# %%
from bs4 import BeautifulSoup
from bs4.element import Tag
soup = BeautifulSoup(html_page)

# %%
soup.select("table.blacktab tbody tr td[rowspan='2']")[0]
# Out:
# <td align="Center" rowspan="2" width="7%">数据库原理及应用A<br/>必修<br/>周一第1,2节{第1-3周|单周}<br/>夏官梦<br/>经管D304<br/><br/>数据库原理及应用A<br/>必修<br/>周一第1,2节{第7-13周|单周}<br/>夏官梦<br/>经管D304</td>

# %%
infos = []
for cls in soup.select("table.blacktab tbody tr td[rowspan='2']"):
    tmpl = []
    for _ in cls.children:
        if type(_) != Tag:
            tmpl.append(_)
            
    infos.append(tmpl)

# %%
tmpl = soup.select("table.blacktab tbody tr td[rowspan='2']")[0]
for i in tmpl.children:
    print(i,end='\n-->')
# Out:
# 数据库原理及应用A
# --><br/>
# -->必修
# --><br/>
# -->周一第1,2节{第1-3周|单周}
# --><br/>
# -->夏官梦
# --><br/>
# -->经管D304
# --><br/>
# --><br/>
# -->数据库原理及应用A
# --><br/>
# -->必修
# --><br/>
# -->周一第1,2节{第7-13周|单周}
# --><br/>
# -->夏官梦
# --><br/>
# -->经管D304
# -->

# %%
classes = []
for info in infos:
    tmpd = {
            "课程名称":info[0],
            "类型":info[1],
            "节次":info[2],
            "教师":info[3],
            "地点":info[4],
        }
    classes.append(tmpd)
    
    if len(info)==10:
        tmpd = {
            "课程名称":info[0],
            "类型":info[1],
            "节次":info[2],
            "教师":info[3],
            "地点":info[4],
        }
    classes.append(tmpd)

print(classes[0])
# Out:
# {'课程名称': '数据库原理及应用A', '类型': '必修', '节次': '周一第1,2节{第1-3周|单周}', '教师': '夏官梦', '地点': '经管D304'}

# %%
print(type(classes[0]['节次']))
print(dir(classes[0]['节次']))
# Out:
# <class 'bs4.element.NavigableString'>
# ...

# %%
classes
# Out:
# [{'课程名称': '数据库原理及应用A',
#   '类型': '必修',
#   '节次': '周一第1,2节{第1-3周|单周}',
#   '教师': '夏官梦',
#   '地点': '经管D304'},
#  {'课程名称': '数据库原理及应用A',
#   '类型': '必修',
#   '节次': '周一第1,2节{第1-3周|单周}',
#   '教师': '夏官梦',
#   '地点': '经管D304'},
#  {'课程名称': '操作系统A',
#   '类型': '必修',
#   '节次': '周二第1,2节{第1-4周}',
#   '教师': '刘晓璐',
#   '地点': '经管D403'},
#  {'课程名称': '操作系统A',
#   '类型': '必修',
#   '节次': '周二第1,2节{第1-4周}',
#   '教师': '刘晓璐',
#   '地点': '经管D403'},
#  {'课程名称': '操作系统A',
#   '类型': '必修',
#   '节次': '周四第1,2节{第1-4周}',
#   '教师': '刘晓璐',
#   '地点': '经管D403'},
#  {'课程名称': '操作系统A',
#   '类型': '必修',
#   '节次': '周四第1,2节{第1-4周}',
#   '教师': '刘晓璐',
#   '地点': '经管D403'},
#  {'课程名称': '计算机组成与结构',
#   '类型': '必修',
#   '节次': '周一第3,4节{第3-3周|单周}',
#   '教师': '钱瑛',
#   '地点': '经管C404'},
#  {'课程名称': '计算机组成与结构',
#   '类型': '必修',
#   '节次': '周一第3,4节{第3-3周|单周}',
#   '教师': '钱瑛',
#   '地点': '经管C404'},
#  {'课程名称': 'WEB开发技术',
#   '类型': '任选',
#   '节次': '周二第3,4节{第1-4周}',
#   '教师': '程初',
#   '地点': '经管D404'},
#  {'课程名称': 'WEB开发技术',
#   '类型': '任选',
# ...
